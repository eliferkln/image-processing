# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
import cv2

# %%
img= cv2.imread('yyyy.jpg')

# %%
plt.imshow(img)

# %%
edges = cv2.Canny(image=img, threshold1=127 , threshold2=127)

# %%
plt.imshow(edges)

# %%
imgg=cv2.blur(img, ksize=(5,5))

# %%
edges = cv2.Canny(image=img, threshold1=0 , threshold2=250)

# %%
plt.imshow(edges)

# %%
imgp= cv2.imread('okj.jpeg')

# %%
plt.imshow(imgp)

# %%
imig=cv2.blur(img, ksize=(5,5))

# %%
edges = cv2.Canny(image=imig, threshold1=0 , threshold2=250)

# %%
plt.imshow(edges)
